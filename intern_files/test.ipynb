# %%
import transformers
import torch

# %%
base_model = "/home/hadoop-aipnlp/dolphinfs_hdd_hadoop-aipnlp/liujincheng06/huggingface/codellama/CodeLlama-7b-hf"

# %%
from transformers import AutoTokenizer,AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained(base_model)

# %%
model = AutoModelForCausalLM.from_pretrained(base_model, trust_remote_code=True, torch_dtype=torch.bfloat16,device_map='auto')

# %%
prompt = "write a python function to sort by using quick sort:"
inputs = tokenizer(prompt,return_tensors="pt")

# %%
inputs

# %%
model(inputs['input_ids'].cuda())
